# %%
# !git clone https://github.com/campusx-official/100-days-of-machine-learning.git
# Out:
# Cloning into '100-days-of-machine-learning'...
# remote: Enumerating objects: 587, done.
# remote: Counting objects: 100% (184/184), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 587 (delta 169), reused 162 (delta 162), pack-reused 403
# Receiving objects: 100% (587/587), 16.81 MiB | 16.30 MiB/s, done.
# Resolving deltas: 100% (227/227), done.

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("/content/100-days-of-machine-learning/day19-understanding-your-data-descriptive-stats/train.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 695          696         0       2      Chapman, Mr. Charles Henry    male
# 35            36         0       1  Holverson, Mr. Alexander Oskar    male
# 123          124         1       2             Webber, Miss. Susan  female
# 884          885         0       3          Sutehall, Mr. Henry Jr    male
# 593          594         0       3              Bourke, Miss. Mary  female
#
#       Age  SibSp  Parch           Ticket   Fare Cabin Embarked
# 695  52.0      0      0           248731  13.50   NaN        S
# 35   42.0      1      0           113789  52.00   NaN        S
# 123  32.5      0      0            27267  13.00  E101        S
# 884  25.0      0      0  SOTON/OQ 392076   7.05   NaN        S
# 593   NaN      0      2           364848   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr()['Survived']
# Out:
# <ipython-input-11-57d70bb92b5b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Survived']
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
df.corr()['Fare']
# Out:
# <ipython-input-12-eaf68b05aa45>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Fare']
# PassengerId    0.012658
# Survived       0.257307
# Pclass        -0.549500
# Age            0.096067
# SibSp          0.159651
# Parch          0.216225
# Fare           1.000000
# Name: Fare, dtype: float64

# %%
df.corr()['Age']
# Out:
# <ipython-input-13-440c5838b7f8>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Age']
# PassengerId    0.036847
# Survived      -0.077221
# Pclass        -0.369226
# Age            1.000000
# SibSp         -0.308247
# Parch         -0.189119
# Fare           0.096067
# Name: Age, dtype: float64

# %%
df=sns.load_dataset("flights")

# %%
df.shape
# Out:
# (144, 3)

# %%
df.sample(5)
# Out:
#      year month  passengers
# 110  1958   Mar         362
# 18   1950   Jul         170
# 121  1959   Feb         342
# 52   1953   May         229
# 67   1954   Aug         293

# %%
df['month'].unique()
# Out:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', ..., 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# Length: 12
# Categories (12, object): ['Jan', 'Feb', 'Mar', 'Apr', ..., 'Sep', 'Oct', 'Nov', 'Dec']

# %%
df['month']=df['month'].replace({'Jan':1, 'Feb':2, 'Mar':3, 'Apr':4, 'May':5,'Jun':6,"Jul":7, 'Aug':8, 'Sep':9, 'Oct':10, 'Nov':11, 'Dec':12})

# %%
df.sample(5)
# Out:
#      year month  passengers
# 74   1955     3         267
# 9    1949    10         119
# 82   1955    11         237
# 95   1956    12         306
# 139  1960     8         606

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
df['month'] = df.month.astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    int64
#  2   passengers  144 non-null    int64
# dtypes: int64(3)
# memory usage: 3.5 KB

# %%
df.corr()['passengers']
# Out:
# year          0.921824
# month         0.063649
# passengers    1.000000
# Name: passengers, dtype: float64

# %%
df.describe()
# Out:
#               year       month  passengers
# count   144.000000  144.000000  144.000000
# mean   1954.500000    6.500000  280.298611
# std       3.464102    3.464102  119.966317
# min    1949.000000    1.000000  104.000000
# 25%    1951.750000    3.750000  180.000000
# 50%    1954.500000    6.500000  265.500000
# 75%    1957.250000    9.250000  360.500000
# max    1960.000000   12.000000  622.000000

# %%
df=sns.load_dataset("taxis")

# %%
df.sample(5)
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 5884 2019-03-11 10:29:53 2019-03-11 10:32:27           2      0.68   4.0
# 826  2019-03-12 22:04:50 2019-03-12 22:13:13           1      1.62   7.5
# 5282 2019-03-07 10:56:58 2019-03-07 11:03:42           2      0.68   6.0
# 2607 2019-03-05 11:06:51 2019-03-05 11:14:54           2      0.48   6.5
# 5057 2019-03-27 11:38:18 2019-03-27 12:11:42           5      8.65  31.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# 5884  0.00    0.0   4.80   green         cash                Astoria
# 826   2.26    0.0  13.56  yellow  credit card            Murray Hill
# 5282  0.00    0.0   9.30  yellow         cash  Upper East Side South
# 2607  0.00    0.0   9.80  yellow         cash           Midtown East
# 5057  0.33    0.0  34.63  yellow  credit card         Midtown Center
#
#                        dropoff_zone pickup_borough dropoff_borough
# ...

# %%
df.shape
# Out:
# (6433, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough'],
#       dtype='object')

# %%
df.describe()
# Out:
#         passengers     distance         fare         tip        tolls  \
# count  6433.000000  6433.000000  6433.000000  6433.00000  6433.000000
# mean      1.539251     3.024617    13.091073     1.97922     0.325273
# std       1.203768     3.827867    11.551804     2.44856     1.415267
# min       0.000000     0.000000     1.000000     0.00000     0.000000
# 25%       1.000000     0.980000     6.500000     0.00000     0.000000
# 50%       1.000000     1.640000     9.500000     1.70000     0.000000
# 75%       2.000000     3.210000    15.000000     2.80000     0.000000
# max       6.000000    36.700000   150.000000    33.20000    24.020000
#
#              total
# count  6433.000000
# mean     18.517794
# std      13.815570
# min       1.300000
# 25%      10.800000
# 50%      14.160000
# 75%      20.300000
# max     174.820000

# %%
df.isnull().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
from statistics import mode

# %%
mode(df['dropoff_borough'])
# Out:
# 'Manhattan'

# %%
df.payment.fillna(mode(df['payment']),inplace=True)

# %%
df.pickup_zone.fillna(mode(df['pickup_zone']),inplace=True)

# %%
df.dropoff_zone.fillna(mode(df['dropoff_zone']),inplace=True)

# %%
df.pickup_borough.fillna(mode(df['pickup_borough']),inplace=True)

# %%
df.dropoff_borough.fillna(mode(df['dropoff_borough']),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6433 non-null   object
#  10  pickup_zone      6433 non-null   object
#  11  dropoff_zone     6433 non-null   object
#  12  pickup_borough   6433 non-null   object
#  13  dropoff_borough  6433 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB

# %%
df.isnull().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %%
df['payment']=df['payment'].replace({'credit card':0, 'cash':1})

# %%
df['payment'].unique()
# Out:
# array([0, 1])

# %%
df['color']=df['color'].replace({'yellow':0, 'green':1})

# %%
df['color'].unique()
# Out:
# array([0, 1])

# %%
df['Dates_pickup'] = pd.to_datetime(df['pickup']).dt.date
df['Time_picup'] = pd.to_datetime(df['pickup']).dt.time

# %%
df['Dates_drop'] = pd.to_datetime(df['dropoff']).dt.date
df['Time_drop'] = pd.to_datetime(df['dropoff']).dt.time

# %%
df.columns
# Out:
# Index(['pickup', 'dropoff', 'passengers', 'distance', 'fare', 'tip', 'tolls',
#        'total', 'color', 'payment', 'pickup_zone', 'dropoff_zone',
#        'pickup_borough', 'dropoff_borough', 'Dates_pickup', 'Time_picup',
#        'Dates_drop', 'Time_drop'],
#       dtype='object')

# %%
df.drop(['pickup', 'dropoff'],axis=1,inplace=True)

# %%
df['date_pick'] = pd.to_datetime(df['Dates_pickup'])

# extract the day, month, and year components
df['day_pick'] = df['date_pick'].dt.day
df['month_pick'] = df['date_pick'].dt.month
df['year_pick'] = df['date_pick'].dt.year

# %%
import datetime as dt

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   passengers       6433 non-null   int64
#  1   distance         6433 non-null   float64
#  2   fare             6433 non-null   float64
#  3   tip              6433 non-null   float64
#  4   tolls            6433 non-null   float64
#  5   total            6433 non-null   float64
#  6   color            6433 non-null   int64
#  7   payment          6433 non-null   int64
#  8   pickup_borough   6433 non-null   int64
#  9   dropoff_borough  6433 non-null   int64
#  10  Time_picup       6433 non-null   object
#  11  Time_drop        6433 non-null   object
#  12  day_pick         6433 non-null   int64
#  13  month_pick       6433 non-null   int64
#  14  day_drop         6433 non-null   int64
#  15  month_drop       6433 non-null   int64
# dtypes: float64(5), int64(9), object(2)
# ...

# %%
df.drop(['date_pick','Dates_pickup'],axis=1,inplace=True)

# %%
df['dates_drop'] = pd.to_datetime(df['Dates_drop'])

# extract the day, month, and year components
df['day_drop'] = df['dates_drop'].dt.day
df['month_drop'] = df['dates_drop'].dt.month
df['year_drop'] = df['dates_drop'].dt.year

# %%
df.drop(['dates_drop','Dates_drop','year_drop','year_pick'],axis=1,inplace=True)

# %%
df['year_drop'].unique()
# Out:
# array([2019])

# %%
df['dropoff_borough']=df['dropoff_borough'].replace({'Manhattan':0, 'Queens':1, 'Brooklyn':2, 'Bronx':3, 'Staten Island':4})

# %%
df.dropoff_borough.unique()
# Out:
# array([0, 1, 2, 3, 4])

# %%
df['pickup_borough']=df['pickup_borough'].replace({'Manhattan':0, 'Queens':1, 'Bronx':2, 'Brooklyn':3})

# %%
df.pickup_borough.unique()
# Out:
# array([0, 1, 2, 3])

# %%
df.drop(['dropoff_zone','pickup_zone'],axis=1,inplace=True)

# %%
df['Time_picup'].head()
# Out:
# 0    20:21:09
# 1    16:11:55
# 2    17:53:01
# 3    01:23:59
# 4    13:27:42
# Name: Time_picup, dtype: object

# %%
df.drop(['Time_picup','Time_drop'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   passengers       6433 non-null   int64
#  1   distance         6433 non-null   float64
#  2   fare             6433 non-null   float64
#  3   tip              6433 non-null   float64
#  4   tolls            6433 non-null   float64
#  5   total            6433 non-null   float64
#  6   color            6433 non-null   int64
#  7   payment          6433 non-null   int64
#  8   pickup_borough   6433 non-null   int64
#  9   dropoff_borough  6433 non-null   int64
#  10  day_pick         6433 non-null   int64
#  11  month_pick       6433 non-null   int64
#  12  day_drop         6433 non-null   int64
#  13  month_drop       6433 non-null   int64
# dtypes: float64(5), int64(9)
# memory usage: 703.7 KB

# %%
df.corr()['fare']
# Out:
# passengers         0.007637
# distance           0.920108
# fare               1.000000
# tip                0.488612
# tolls              0.609307
# total              0.974358
# color              0.034901
# payment           -0.081214
# pickup_borough     0.230385
# dropoff_borough    0.272335
# day_pick          -0.003597
# month_pick         0.008734
# day_drop          -0.004410
# month_drop         0.024424
# Name: fare, dtype: float64

# %%
sns.histplot(data=df,x='fare',hue='tip',bins=8)
# Out:
# <Axes: xlabel='fare', ylabel='Count'>

# %%
sns.histplot(data=df,x='payment',hue='color',bins=8)
# Out:
# <Axes: xlabel='payment', ylabel='Count'>

# %%
df1['payment'].unique()
# Out:
# array(['credit card', 'cash', nan], dtype=object)

# %%
df1['color'].unique()
# Out:
# array(['yellow', 'green'], dtype=object)

# %%
plt.figure(figsize=(8, 8))
plt.pie(df['fare'], labels=df['payment'], autopct='%2f%%', startangle=140)
plt.title('Pie Chart fare')
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
