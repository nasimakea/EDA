# %%
pip install opendatasets --upgrade

# %%
import opendatasets as od
dataset_url = 'https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset'
od.download('https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset')
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: nasimakram
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/karkavelrajaj/amazon-sales-dataset
# ...
# 100%|██████████| 1.95M/1.95M [00:01<00:00, 1.79MB/s]

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as  np
from statistics import math

# %%
df_copy=pd.read_csv("/content/amazon-sales-dataset/amazon.csv")

# %%
df=df_copy.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
len(df['product_id'])
# Out:
# 1465

# %%
df['rating_count']
# Out:
# 0       24,269
# 1       43,994
# 2        7,928
# 3       94,363
# 4       16,905
#          ...
# 1460     1,090
# 1461     4,118
# 1462       468
# 1463     8,031
# 1464     6,987
# Name: rating_count, Length: 1465, dtype: object

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
len(df['product_name'].unique())
# Out:
# 1337

# %% [markdown]
# # The total 1337 products are availabile on the amazon site

# %%
df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# ...

# %%
len(df['user_id'][1])
# Out:
# 'AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBXNGXZJT525AQ,AHONIZU3ICIEHQIGQ6R2VFRSBXOQ,AFPHD2CRPDZMWMBL7WXRSVYWS5JA,AEZ346GX3HJ4O4XNRPHCNHXQURMQ,AEPSWFPNECKO34PUC7I56ITGXR6Q,AHWVEHR5DYLVFTO2KF3IZATFQSWQ,AH4QT33M55677I7ISQOAKEQWACYQ'

# %%
df['user_name'][1]
# Out:
# 'ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Placeholder,BharanI,sonia,Niam'

# %%
df['discounted_price'].unique()
# Out:
# array(['₹399', '₹199', '₹329', '₹154', '₹149', '₹176.63', '₹229', '₹499',
#        '₹299', '₹219', '₹350', '₹159', '₹349', '₹13,999', '₹249',
#        '₹13,490', '₹970', '₹279', '₹59', '₹11,499', '₹14,999', '₹179',
#        '₹389', '₹599', '₹99', '₹899', '₹32,999', '₹209', '₹19,999',
#        '₹999', '₹333', '₹507', '₹309', '₹1,199', '₹799', '₹6,999', '₹230',
#        '₹649', '₹15,999', '₹348', '₹32,990', '₹139', '₹263', '₹7,999',
#        '₹1,599', '₹26,999', '₹115', '₹10,901', '₹1,434', '₹7,299', '₹325',
#        '₹29,999', '₹27,999', '₹30,990', '₹269', '₹24,999', '₹18,990',
#        '₹290', '₹345', '₹1,099', '₹719', '₹849', '₹21,999', '₹449',
#        '₹37,999', '₹7,390', '₹273.10', '₹15,990', '₹210', '₹1,299',
#        '₹347', '₹228', '₹1,499', '₹8,499', '₹20,990', '₹9,999', '₹489',
#        '₹23,999', '₹689', '₹1,699', '₹655', '₹749', '₹195', '₹416',
#        '₹368', '₹29,990', '₹339', '₹15,490', '₹9,490', '₹637', '₹1,089',
# ...

# %%
def remover(a):
  for i in range(len(a)):
    if a[i][0]=='₹' :


      a[i]=a[i][1:]
    else :
      if a[i][-1]=='%':
        a[i]=a[i][:-1]

  return(a)

# %%
df['discounted_price']=remover(df['discounted_price'])

# %%
remover(df['discount_percentage'])
# Out:
# 0       64
# 1       43
# 2       90
# 3       53
# 4       61
#         ..
# 1460    59
# 1461    25
# 1462    28
# 1463    26
# 1464    22
# Name: discount_percentage, Length: 1465, dtype: object

# %%
df['discount_percentage']
# Out:
# 0       64
# 1       43
# 2       90
# 3       53
# 4       61
#         ..
# 1460    59
# 1461    25
# 1462    28
# 1463    26
# 1464    22
# Name: discount_percentage, Length: 1465, dtype: object

# %%
remover(df['actual_price'])
# Out:
# 0       1,099
# 1         349
# 2       1,899
# 3         699
# 4         399
#         ...
# 1460      919
# 1461    3,045
# 1462    3,080
# 1463    1,890
# 1464    3,690
# Name: actual_price, Length: 1465, dtype: object

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...              399
# 1  Computers&Accessories|Accessories&Peripherals|...              199
# 2  Computers&Accessories|Accessories&Peripherals|...              199
# 3  Computers&Accessories|Accessories&Peripherals|...              329
# 4  Computers&Accessories|Accessories&Peripherals|...              154
#
#   actual_price discount_percentage rating rating_count  \
# 0        1,099                  64    4.2       24,269
# ...

# %%
df['discounted_price'].unique()
# Out:
# array(['399', '199', '329', '154', '149', '176.63', '229', '499', '299',
#        '219', '350', '159', '349', '13999', '249', '13490', '970', '279',
#        '59', '11499', '14999', '179', '389', '599', '99', '899', '32999',
#        '209', '19999', '999', '333', '507', '309', '1199', '799', '6999',
#        '230', '649', '15999', '348', '32990', '139', '263', '7999',
#        '1599', '26999', '115', '10901', '1434', '7299', '325', '29999',
#        '27999', '30990', '269', '24999', '18990', '290', '345', '1099',
#        '719', '849', '21999', '449', '37999', '7390', '273.10', '15990',
#        '210', '1299', '347', '228', '1499', '8499', '20990', '9999',
#        '489', '23999', '689', '1699', '655', '749', '195', '416', '368',
#        '29990', '339', '15490', '9490', '637', '1089', '12499', '1399',
#        '88', '57.89', '205', '949', '379', '8990', '486', '5699', '709',
#        '47990', '320', '129', '225', '547', '259', '239', '467', '11990',
# ...

# %%
def comma_remover(a):
  for i in range(len(a)):
    for j in range(len(a[i])):
      if a[i][j]==',':
        a[i]=a[i][0:j]+a[i][j+1:]
        break

  return(a)

# %%
comma_remover(df['discounted_price'])
# Out:
# 0        399
# 1        199
# 2        199
# 3        329
# 4        154
#         ...
# 1460     379
# 1461    2280
# 1462    2219
# 1463    1399
# 1464    2863
# Name: discounted_price, Length: 1465, dtype: object

# %%
a=['NasimAkram']

# %%
a[0][0:3]+a[0][4:]
# Out:
# 'NasmAkram'

# %%
df['discounted_price']=df['discounted_price'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df['actual_price'].unique()
# Out:
# array(['1,099', '349', '1,899', '699', '399', '1,000', '499', '299',
#        '999', '339', '799', '700', '899', '24,999', '21,990', '1,799',
#        '22,900', '199', '19,990', '19,999', '1,999', '750', '599',
#        '666.66', '1,900', '45,999', '695', '34,999', '1,599', '1,208',
#        '475', '395', '2,199', '500', '2,100', '12,999', '1,399', '21,999',
#        '1,499', '47,900', '845', '1,400', '14,990', '2,999', '42,999',
#        '30,990', '3,999', '249', '19,125', '1,299', '39,999', '40,990',
#        '52,900', '800', '31,999', '1,809', '29,999', '65,000', '20,000',
#        '23,990', '15,999', '44,990', '44,999', '1,700', '595', '27,990',
#        '1,200', '34,990', '1,500', '49,990', '931', '2,399', '1,339',
#        '20,900', '15,990', '1,600', '849', '1,199', '22,990', '2,499',
#        '47,990', '485', '18,990', '11,000', '70,900', '549', '35,999',
#        '1,699', '31,990', '9,990', '16,990', '59,999', '600', '1,490',
# ...

# %%
comma_remover(df['actual_price'])
# Out:
# <ipython-input-49-8ad4d48b3e23>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[i]=a[i][0:j]+a[i][j+1:]
# <ipython-input-49-8ad4d48b3e23>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[i]=a[i][0:j]+a[i][j+1:]
# <ipython-input-49-8ad4d48b3e23>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[i]=a[i][0:j]+a[i][j+1:]
# <ipython-input-49-8ad4d48b3e23>:5: SettingWithCopyWarning:
# ...

# %%
df['actual_price']=df['actual_price'].astype(float)

# %%
comma_remover(df['actual_price'])
# Out:
# <ipython-input-49-8ad4d48b3e23>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a[i]=a[i][0:j]+a[i][j+1:]
# 0       1099
# 1        349
# 2       1899
# 3        699
# 4        399
#         ...
# 1460     919
# 1461    3045
# 1462    3080
# 1463    1890
# 1464    3690
# Name: actual_price, Length: 1465, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df['discount_percentage'].unique()
# Out:
# array(['64', '43', '90', '53', '61', '85', '65', '23', '50', '33', '55',
#        '63', '69', '60', '13', '44', '38', '39', '46', '41', '70', '42',
#        '72', '25', '51', '73', '0', '80', '28', '67', '58', '35', '45',
#        '62', '54', '27', '77', '56', '78', '31', '86', '47', '37', '75',
#        '32', '68', '66', '22', '57', '17', '52', '88', '20', '59', '40',
#        '26', '29', '83', '71', '15', '76', '48', '82', '36', '89', '87',
#        '24', '34', '11', '91', '7', '19', '79', '21', '81', '18', '49',
#        '30', '84', '10', '6', '14', '74', '4', '5', '16', '8', '2', '94',
#        '12', '3', '9'], dtype=object)

# %%
df['discount_percentage']=df['discount_percentage'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   int64
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df[df['rating']=='|']
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage rating rating_count  \
# 1279        2499.0                   16      |          992
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %%
df[df['rating']=='|']
# Out:
# Empty DataFrame
# Columns: [product_id, product_name, category, discounted_price, actual_price, discount_percentage, rating, rating_count, about_product, user_id, user_name, review_id, review_title, review_content, img_link, product_link]
# Index: []

# %%
df.drop(index=1279,axis=0,inplace=True)

# %%
from statistics import mode

# %%
df['rating']=df['rating'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1464 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1464 non-null   object
#  1   product_name         1464 non-null   object
#  2   category             1464 non-null   object
#  3   discounted_price     1464 non-null   float64
#  4   actual_price         1464 non-null   float64
#  5   discount_percentage  1464 non-null   int64
#  6   rating               1464 non-null   float64
#  7   rating_count         1462 non-null   object
#  8   about_product        1464 non-null   object
#  9   user_id              1464 non-null   object
#  10  user_name            1464 non-null   object
#  11  review_id            1464 non-null   object
#  12  review_title         1464 non-null   object
#  13  review_content       1464 non-null   object
#  14  img_link             1464 non-null   object
# ...

# %%
df[df['rating_count'].isnull()]
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating rating_count  \
# 282         999.0                   80     3.0          NaN
# 324         999.0                   75     5.0          NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# ...

# %%
mode(df['rating_count'])
# Out:
# '18,998'

# %%
df['rating_count'].fillna(mode(df['rating_count']),inplace=True)

# %%
comma_remover(df['rating_count'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1279
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-ddac0742032b> in <cell line: 1>()
# ----> 1 comma_remover(df['rating_count'])
#
# ...

# %%
df['rating_count'].unique()
# Out:
# array(['24269', '43994', '7928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %%
def comma_remover(a):
  for i in range(len(a)):
    if i==1279:
      continue


    for j in range(len(a[i])):
      if a[i][j]==',':
        a[i]=a[i][0:j]+a[i][j+1:]

        break

  return(a)

# %%
comma_remover(df['rating_count'])
# Out:
# 0       24269
# 1       43994
# 2        7928
# 3       94363
# 4       16905
#         ...
# 1460     1090
# 1461     4118
# 1462      468
# 1463     8031
# 1464    6,987
# Name: rating_count, Length: 1464, dtype: object

# %%
df_copy['rating_count'].unique()
# Out:
# array(['24,269', '43,994', '7,928', ..., '468', '8,031', '6,987'],
#       dtype=object)

# %%
df['rating_count'].unique()
# Out:
# array(['24269', '43994', '7928', ..., '468', '8031', '6,987'],
#       dtype=object)

# %%
df[df['rating_count']=='6,987']
# Out:
#       product_id                                       product_name  \
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category  discounted_price  \
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...            2863.0
#
#       actual_price  discount_percentage  rating rating_count  \
# 1464        3690.0                   22     4.3        6,987
#
#                                           about_product  \
# 1464  Brand-Borosil, Specification â€“ 23V ~ 5Hz;1 W...
#
#                                                 user_id  \
# 1464  AFGW5PT3R6ZAVQR4Y5MWVAKBZAYA,AG7QNJ2SCS5VS5VYY...
#
#                                               user_name  \
# 1464  Rajib,Ajay B,Vikas Kahol,PARDEEP,Anindya Prama...
#
#                                               review_id  \
# 1464  R20RBRZ0WEUJT9,ROKIFK9R2ISSE,R30EEG2FNJSN5I,R2...
#
#                                            review_title  \
# ...

# %%
df['rating_count'][1464]='6987'

# %%
df['rating_count'].unique()
# Out:
# array(['24269', '43994', '7928', ..., '468', '8031', '6987'], dtype=object)

# %%
df['rating_count'].unique()
# Out:
# array(['24269', '43994', '7928', ..., '468', '8031', '6987'], dtype=object)

# %%
df['rating_count']=df['rating_count'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1464 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1464 non-null   object
#  1   product_name         1464 non-null   object
#  2   category             1464 non-null   object
#  3   discounted_price     1464 non-null   float64
#  4   actual_price         1464 non-null   float64
#  5   discount_percentage  1464 non-null   int64
#  6   rating               1464 non-null   float64
#  7   rating_count         1464 non-null   int64
#  8   about_product        1464 non-null   object
#  9   user_id              1464 non-null   object
#  10  user_name            1464 non-null   object
#  11  review_id            1464 non-null   object
#  12  review_title         1464 non-null   object
#  13  review_content       1464 non-null   object
#  14  img_link             1464 non-null   object
# ...

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
# 3  Computers&Accessories|Accessories&Peripherals|...             329.0
# 4  Computers&Accessories|Accessories&Peripherals|...             154.0
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0        1099.0                   64     4.2         24269
# ...

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df[['discounted_price','actual_price', 'discount_percentage', 'rating', 'rating_count']].corr()
# Out:
#                      discounted_price  actual_price  discount_percentage  \
# discounted_price             1.000000      0.961919            -0.242740
# actual_price                 0.961919      1.000000            -0.118459
# discount_percentage         -0.242740     -0.118459             1.000000
# rating                       0.120337      0.121642            -0.155375
# rating_count                -0.027310     -0.036220             0.011310
#
#                        rating  rating_count
# discounted_price     0.120337     -0.027310
# actual_price         0.121642     -0.036220
# discount_percentage -0.155375      0.011310
# rating               1.000000      0.101395
# rating_count         0.101395      1.000000

# %%
df.dtypes=='object'
# Out:
# product_id              True
# product_name            True
# category                True
# discounted_price       False
# actual_price           False
# discount_percentage    False
# rating                 False
# rating_count           False
# about_product           True
# user_id                 True
# user_name               True
# review_id               True
# review_title            True
# review_content          True
# img_link                True
# product_link            True
# dtype: bool
